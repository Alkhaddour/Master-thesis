# %%
import librosa

# %%
audio_path = '/home/alhasan/workdir/SED/data/AudioSet/raw/Baby cry, infant cry/1TB3-XSom_A_30.wav'

# %%
waveform, _ = librosa.core.load(audio_path,sr=None, mono=True)

# %%
len(waveform)
# Out:
# 160000

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(waveform)
plt.show()

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
plt.figure(2)
input_data = read(audio_path)
audio = input_data[1]
# plot the first 1024 samples
plt.plot(audio)
plt.show()
#------
audio2 = librosa.util.normalize(audio)
plt.figure(3)
audio = input_data[1]
# plot the first 1024 samples
plt.plot(audio2)
plt.show()

# %%
import soundfile as sf

# Read wav with default
audio= sf.read(audio_path)[0]
# plot the first 1024 samples
plt.plot(audio)
# label the axes
plt.ylabel("Amplitude")
plt.xlabel("Time")
# set the title  
plt.title("Sample Wav")
# display the plot
plt.show()
